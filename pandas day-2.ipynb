# %% [markdown]
# ## Extract deta from web page (HTML)

# %%
import pandas as pd

# side link:- https://www.basketball-reference.com/leagues/NBA_2015_totals.html

# %%
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")


# it can scrap data which are avilabke into tabular format only 

# read_html does not able to read data which is not in table format
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[["Age","GS"]]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
# Add this data into any other format like csv or excel

df1.to_csv("NBA.csv",index=False)  # by doing index= false it does not save index in file

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 44A5-598D
#
#  Directory of C:\Users\aakas\Documents\INeuron\pandas and Numpy
#
# 02-12-2022  21:19    <DIR>          .
# 02-12-2022  21:19    <DIR>          ..
# 02-12-2022  18:32    <DIR>          .ipynb_checkpoints
# 02-12-2022  16:17            61,453 introduction to pandas.ipynb
# 02-12-2022  21:19            81,552 NBA.csv
# 02-12-2022  21:17            24,535 pandas day2.ipynb
# 01-12-2022  19:58               254 sample_test.csv
#                4 File(s)        167,794 bytes
#                3 Dir(s)  227,274,481,664 bytes free

# %%
l=pd.read_html("https://stats.espncricinfo.com/CI/content/records/282910.html")

# %%
len(l)
# Out:
# 3

# %%
l[0]
# Out:
#                       Player       Span   Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948    52    80  10   6996   334  99.94
# 1             AC Voges (AUS)  2015-2016    20    31   7   1485  269*  61.87
# 2            SPD Smith (AUS)  2010-2022   88*   155  19   8361   239  61.47
# 3            RG Pollock (SA)  1963-1970    23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954    22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935    54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939    20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968    82   131  15   6806   256  58.67
# 8             ED Weekes (WI)  1948-1958    48    81   5   4455   207  58.61
# 9           WR Hammond (ENG)  1927-1947    85   140  16   7249  336*  58.45
# 10            GS Sobers (WI)  1954-1974    93   160  21   8032  365*  57.78
# ...

# %%
l[0].to_csv("cricket_data.csv",index=False)

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  Pakistan v England at Rawalpindi, 1st Test, De...
# 2  Australia v West Indies at Perth, 1st Test, No...
# 3  England v South Africa at The Oval, 3rd Test, ...

# %% [markdown]
# ### How to read json file

# %%
d='''                            
{"name":"aakash",
"emailid":"aakashsolanke",
"tech":["ml","dl","cv"],
"platform":["techneuron","ineuron","kidneuron"]

}
'''

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result=json.loads(d)

# %%
result  # data is must have same length
# Out:
# {'name': 'aakash',
#  'emailid': 'aakashsolanke',
#  'tech': ['ml', 'dl', 'cv'],
#  'platform': ['techneuron', 'ineuron', 'kidneuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#      name        emailid tech    platform
# 0  aakash  aakashsolanke   ml  techneuron
# 1  aakash  aakashsolanke   dl     ineuron
# 2  aakash  aakashsolanke   cv   kidneuron

# %%
pd.DataFrame(result["tech"])
# Out:
#     0
# 0  ml
# 1  dl
# 2  cv

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")


# by using json its get complex because in data there is some another data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
# for data in row format

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1      # now data is in row format
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50064',
#   'id': 1475603882,
#   'node_id': 'PR_kwDOAA0YD85ESnNN',
#   'number': 50064,
#   'title': 'DEPR: Enforce DataFrameGroupBy.__iter__ returning tuples of length 1',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
len(data1)
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/50064',
#  'id': 1475603882,
#  'node_id': 'PR_kwDOAA0YD85ESnNN',
#  'number': 50064,
#  'title': 'DEPR: Enforce DataFrameGroupBy.__iter__ returning tuples of length 1',
#  'user': {'login': 'rhshadrach',
#   'id': 45562402,
#   'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rhshadrach',
#   'html_url': 'https://github.com/rhshadrach',
# ...

# %%
data1[0]["user"]
# Out:
# {'login': 'rhshadrach',
#  'id': 45562402,
#  'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rhshadrach',
#  'html_url': 'https://github.com/rhshadrach',
#  'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#  'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#  'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#  'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#  'type': 'User',
# ...

# %%
data1[0]["user"]["id"]
# Out:
# 45562402

# %%
for i in range(len(data1)):                          # to get user id 
    print(data1[i]["user"]["id"])
# Out:
# 45562402
# 45562402
# 28446653
# 116989963
# 116989963
# 33491632
# 61934744
# 50991099
# 47963215
# 33491632
# 28446653
# 26364415
# 33491632
# 32019551
# 10820686
# 61934744
# 61934744
# 609873
# 37235937
# 26364415
# 26364415
# 13590797
# 25847554
# 8078968
# 18587013
# 8078968
# 18587013
# 8078968
# 33491632
# 73792888

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50064/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50064',
#   'id': 1475603882,
#   'node_id': 'PR_kwDOAA0YD85ESnNN',
#   'number': 50064,
#   'title': 'DEPR: Enforce DataFrameGroupBy.__iter__ returning tuples of length 1',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
pd.DataFrame(data1,columns=["id","url","repository_url","labels_url","user"])
# Out:
#             id                                                url  \
# 0   1475603882  https://api.github.com/repos/pandas-dev/pandas...
# 1   1475501589  https://api.github.com/repos/pandas-dev/pandas...
# 2   1475421765  https://api.github.com/repos/pandas-dev/pandas...
# 3   1475268297  https://api.github.com/repos/pandas-dev/pandas...
# 4   1475266982  https://api.github.com/repos/pandas-dev/pandas...
# 5   1475085032  https://api.github.com/repos/pandas-dev/pandas...
# 6   1475026595  https://api.github.com/repos/pandas-dev/pandas...
# 7   1474964398  https://api.github.com/repos/pandas-dev/pandas...
# 8   1474962707  https://api.github.com/repos/pandas-dev/pandas...
# 9   1474871926  https://api.github.com/repos/pandas-dev/pandas...
# 10  1474804774  https://api.github.com/repos/pandas-dev/pandas...
# 11  1474739624  https://api.github.com/repos/pandas-dev/pandas...
# 12  1474732854  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df2=pd.DataFrame(data1,columns=["id","url","repository_url","labels_url","user"])

# %%
df2.to_csv("jeson_res.csv")

# %% [markdown]
# ## task:- seprate user daa into diffrent diffrent table
#
#
# - import pandas as pd
# -li=[]
# -for i in range(len(data1)):
# -    df3=(data1[i]["user"])
# -    li.append(df3)
#
# -import pandas as pd
#
# -df3=pd.DataFrame(li)
#
# -df3

# %%
# task:- seprate user daa into diffrent diffrent table 
for i in range(len(data1)):
    da=pd.DataFrame(data1[i]["user"],index=[0])
    da.to_json("json_user.csv")
    print(da)
# Out:
#         login        id               node_id  \
# 0  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/455624...
#
#                                        url                       html_url  \
# 0  https://api.github.com/users/rhshadrach  https://github.com/rhshadrach
#
#                                        followers_url  \
# 0  https://api.github.com/users/rhshadrach/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/rhshadrach/follow...
#
#                                            gists_url  \
# 0  https://api.github.com/users/rhshadrach/gists{...
#
#                                          starred_url  \
# 0  https://api.github.com/users/rhshadrach/starre...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/rhshadrach/subscr...
#
# ...

# %%
for i in range(len(data1)):
    print(data1[0]["user"])
# Out:
# {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}
# ...

# %%
import pandas as pd
li=[]
for i in range(len(data1)):
    df3=pd.DataFrame(data1[i]["user"],index=[i],columns=["login","id","node_id"])
    li.append(df3)

# %%
li
# Out:
# [        login        id               node_id
#  0  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy,
#          login        id               node_id
#  1  rhshadrach  45562402  MDQ6VXNlcjQ1NTYyNDAy,
#           login        id               node_id
#  2  thanhbui221  28446653  MDQ6VXNlcjI4NDQ2NjUz,
#        login         id       node_id
#  3  codamuse  116989963  U_kgDOBvkgCw,
#        login         id       node_id
#  4  codamuse  116989963  U_kgDOBvkgCw,
#            login        id               node_id
#  5  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy,
#     login        id               node_id
#  6  phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0,
#      login        id               node_id
#  7  iofall  50991099  MDQ6VXNlcjUwOTkxMDk5,
#         login        id               node_id
#  8  lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1,
#            login        id               node_id
#  9  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy,
#            login        id               node_id
# ...

# %%
import pandas as pd
pd.DataFrame([li,columns=["login","id","node_id"]])
# Out:
#   Input In [69]
#     pd.DataFrame([li,columns=["login","id","node_id"]])
#                             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd    # solution of hw
li=[]
for i in range(len(data1)):
    df3=(data1[i]["user"])
    li.append(df3)

# %%
li
# Out:
# [{'login': 'rhshadrach',
#   'id': 45562402,
#   'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rhshadrach',
#   'html_url': 'https://github.com/rhshadrach',
#   'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#   'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#   'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#   'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#   'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd    # solution of hw
df3=pd.DataFrame(li)

# %%
df3
# Out:
#               login         id               node_id  \
# 0        rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 1        rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2       thanhbui221   28446653  MDQ6VXNlcjI4NDQ2NjUz
# 3          codamuse  116989963          U_kgDOBvkgCw
# 4          codamuse  116989963          U_kgDOBvkgCw
# 5      MarcoGorelli   33491632  MDQ6VXNlcjMzNDkxNjMy
# 6             phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 7            iofall   50991099  MDQ6VXNlcjUwOTkxMDk5
# 8         lithomas1   47963215  MDQ6VXNlcjQ3OTYzMjE1
# 9      MarcoGorelli   33491632  MDQ6VXNlcjMzNDkxNjMy
# 10      thanhbui221   28446653  MDQ6VXNlcjI4NDQ2NjUz
# 11       topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 12     MarcoGorelli   33491632  MDQ6VXNlcjMzNDkxNjMy
# 13    georgemunyoro   32019551  MDQ6VXNlcjMyMDE5NTUx
# 14        NickCrews   10820686  MDQ6VXNlcjEwODIwNjg2
# 15            phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 16            phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# ...

# %%
import pandas as pd

# %%
df3.to_csv("new_jeson.csv")
csv1=pd.read_csv("new_jeson.csv")

# %%
df2.to_csv("jeson_res.csv")
csv2=pd.read_csv("jeson_res.csv")

# %%
con=pd.concat([csv2,csv1])
con
# Out:
#     Unnamed: 0          id                                                url  \
# 0            0  1475603882  https://api.github.com/repos/pandas-dev/pandas...
# 1            1  1475501589  https://api.github.com/repos/pandas-dev/pandas...
# 2            2  1475421765  https://api.github.com/repos/pandas-dev/pandas...
# 3            3  1475268297  https://api.github.com/repos/pandas-dev/pandas...
# 4            4  1475266982  https://api.github.com/repos/pandas-dev/pandas...
# 5            5  1475085032  https://api.github.com/repos/pandas-dev/pandas...
# 6            6  1475026595  https://api.github.com/repos/pandas-dev/pandas...
# 7            7  1474964398  https://api.github.com/repos/pandas-dev/pandas...
# 8            8  1474962707  https://api.github.com/repos/pandas-dev/pandas...
# 9            9  1474871926  https://api.github.com/repos/pandas-dev/pandas...
# 10          10  1474804774  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
con.to_csv("merge_csv.csv")
